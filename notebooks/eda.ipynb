# %%
from ccsopt.utils import setrootdir

setrootdir("ccsopt")
# Out:
# 'Directory ccsopt successfully loaded as current working directory.'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data/Concrete_Data.xls")
df.columns = [
    "cement",
    "blastFurnaceSlag",
    "flyAsh",
    "water",
    "superplasticizer",
    "coarseAggregate",
    "fineAggregate",
    "age",
    "compressiveStrength"
]
df
# Out:
#       cement  blastFurnaceSlag  flyAsh  water  superplasticizer  \
# 0      540.0               0.0     0.0  162.0               2.5
# 1      540.0               0.0     0.0  162.0               2.5
# 2      332.5             142.5     0.0  228.0               0.0
# 3      332.5             142.5     0.0  228.0               0.0
# 4      198.6             132.4     0.0  192.0               0.0
# ...      ...               ...     ...    ...               ...
# 1025   276.4             116.0    90.3  179.6               8.9
# 1026   322.2               0.0   115.6  196.0              10.4
# 1027   148.5             139.4   108.6  192.7               6.1
# 1028   159.1             186.7     0.0  175.6              11.3
# 1029   260.9             100.5    78.3  200.6               8.6
#
#       coarseAggregate  fineAggregate  age  compressiveStrength
# 0              1040.0          676.0   28            79.986111
# 1              1055.0          676.0   28            61.887366
# ...

# %%
df.iloc[:,:-2].sum(axis=1).mean()
# Out:
# np.float64(2343.515199029126)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ac4e2_row0_col0, #T_ac4e2_row1_col1, #T_ac4e2_row2_col2, #T_ac4e2_row3_col3, #T_ac4e2_row4_col4, #T_ac4e2_row5_col5, #T_ac4e2_row6_col6, #T_ac4e2_row7_col7, #T_ac4e2_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ac4e2_row0_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ac4e2_row0_col2, #T_ac4e2_row1_col5, #T_ac4e2_row2_col0, #T_ac4e2_row2_col1, #T_ac4e2_row3_col4, #T_ac4e2_row3_col6, #T_ac4e2_row3_col8, #T_ac4e2_row4_col3, #T_ac4e2_row4_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ac4e2_row0_col3, #T_ac4e2_row8_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ac4e2_row0_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ac4e2_row0_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ac4e2_row0_col6, #T_ac4e2_row5_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ac4e2_row0_col7 {
#   background-color: #85a8fc;
# ...
